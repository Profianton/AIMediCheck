# %%
# !unzip /content/drive/MyDrive/pills/pill_pretrain.v1i.yolov8.zip -d /content/drive/MyDrive/pills/pill_pretrain
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-19-15a6e60957e3> in <cell line: 1>()
# ----> 1 get_ipython().system('unzip /content/drive/MyDrive/pills/pill_pretrain.v1i.yolov8.zip -d /content/drive/MyDrive/pills/pill_pretrain')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      97       kwargs.update({'also_return_output': True})
#      98
# ---> 99     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     100
#     101     if pip_warn:
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     452   # is expected to call this function, thus adding one level of nesting to the
#     453   # stack.
# --> 454   result = _run_command(
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 903.1/903.1 kB 47.1 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !ls
# Out:
# drive  sample_data

# %%
# Load a model
model = YOLO("/content/drive/MyDrive/pills/Pretrained.pt")  # load a pretrained model (recommended for training)

# %%
results = model.train(data="/content/drive/MyDrive/pills/Pill_train/data.yaml", epochs=30, imgsz=640)
# Out:
# Ultralytics 8.3.54 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model.save("trained.pt")
